-- %% [markdown]
-- # [segurapp]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [segurapp]    Script Date: 16/10/2025 6:36:14 p. m. ******/
CREATE DATABASE [segurapp]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'segurapp', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\segurapp.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'segurapp_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\segurapp_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [segurapp] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [segurapp].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [segurapp] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [segurapp] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [segurapp] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [segurapp] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [segurapp] SET ARITHABORT OFF 
GO
ALTER DATABASE [segurapp] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [segurapp] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [segurapp] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [segurapp] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [segurapp] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [segurapp] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [segurapp] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [segurapp] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [segurapp] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [segurapp] SET  ENABLE_BROKER 
GO
ALTER DATABASE [segurapp] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [segurapp] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [segurapp] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [segurapp] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [segurapp] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [segurapp] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [segurapp] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [segurapp] SET RECOVERY FULL 
GO
ALTER DATABASE [segurapp] SET  MULTI_USER 
GO
ALTER DATABASE [segurapp] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [segurapp] SET DB_CHAINING OFF 
GO
ALTER DATABASE [segurapp] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [segurapp] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [segurapp] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [segurapp] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'segurapp', N'ON'
GO
ALTER DATABASE [segurapp] SET QUERY_STORE = ON
GO
ALTER DATABASE [segurapp] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[cancelacion]

-- %%
USE [segurapp]
GO

-- %%
/****** Object:  Table [dbo].[cancelacion]    Script Date: 16/10/2025 6:36:14 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cancelacion](
	[cancelacion_id] [int] IDENTITY(1,1) NOT NULL,
	[documento] [int] NOT NULL,
	[poliza_id] [int] NOT NULL,
	[estado] [varchar](30) NOT NULL,
	[razon] [varchar](30) NOT NULL,
 CONSTRAINT [PK_cancelacion] PRIMARY KEY CLUSTERED 
(
	[cancelacion_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[estadistica]

-- %%
/****** Object:  Table [dbo].[estadistica]    Script Date: 16/10/2025 6:36:14 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[estadistica](
	[estadistica_id] [int] IDENTITY(1,1) NOT NULL,
	[pago_id] [int] NULL,
	[seguro_tipo] [varchar](30) NULL,
	[fecha] [smalldatetime] NULL,
	[documento] [int] NULL,
	[usuario] [varchar](50) NULL,
	[region] [varchar](50) NULL,
 CONSTRAINT [PK_estadistica] PRIMARY KEY CLUSTERED 
(
	[estadistica_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[pago]

-- %%
/****** Object:  Table [dbo].[pago]    Script Date: 16/10/2025 6:36:14 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[pago](
	[pago_id] [int] IDENTITY(1,1) NOT NULL,
	[pago_tipo] [varchar](40) NULL,
	[cancelacion_id] [int] NULL,
	[monto] [float] NULL,
	[fecha] [smalldatetime] NULL,
	[cuotas] [int] NULL,
 CONSTRAINT [PK_pago] PRIMARY KEY CLUSTERED 
(
	[pago_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[poliza]

-- %%
/****** Object:  Table [dbo].[poliza]    Script Date: 16/10/2025 6:36:14 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[poliza](
	[poliza_id] [int] IDENTITY(1,1) NOT NULL,
	[seguro_id] [int] NULL,
 CONSTRAINT [PK_poliza] PRIMARY KEY CLUSTERED 
(
	[poliza_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[seguro]

-- %%
/****** Object:  Table [dbo].[seguro]    Script Date: 16/10/2025 6:36:14 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[seguro](
	[seguro_id] [int] IDENTITY(1,1) NOT NULL,
	[tipo] [varchar](30) NULL,
	[cobertura] [varchar](50) NULL,
	[costo] [float] NULL,
	[duracion] [smalldatetime] NULL,
	[aseguradora] [varchar](50) NULL,
	[beneficios] [varchar](500) NULL,
	[exclusiones] [varchar](500) NULL,
	[condiciones] [varchar](500) NULL,
	[region] [varchar](50) NOT NULL,
 CONSTRAINT [PK_seguro] PRIMARY KEY CLUSTERED 
(
	[seguro_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[usuario]

-- %%
/****** Object:  Table [dbo].[usuario]    Script Date: 16/10/2025 6:36:14 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[usuario](
	[documento] [int] NOT NULL,
	[nombre] [varchar](50) NULL,
	[tipo_documento] [varchar](10) NULL,
	[puntaje_crediticio] [int] NULL,
	[telefono] [varchar](20) NULL,
	[email] [varchar](50) NULL,
	[rol] [varchar](20) NULL,
	[edad] [int] NULL,
	[password] [varchar](50) NOT NULL,
 CONSTRAINT [PK_usuario] PRIMARY KEY CLUSTERED 
(
	[documento] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_cancelacion_poliza]

-- %%
ALTER TABLE [dbo].[cancelacion]  WITH CHECK ADD  CONSTRAINT [FK_cancelacion_poliza] FOREIGN KEY([poliza_id])
REFERENCES [dbo].[poliza] ([poliza_id])
GO
ALTER TABLE [dbo].[cancelacion] CHECK CONSTRAINT [FK_cancelacion_poliza]
GO

-- %% [markdown]
-- # [FK_cancelacion_usuario]

-- %%
ALTER TABLE [dbo].[cancelacion]  WITH CHECK ADD  CONSTRAINT [FK_cancelacion_usuario] FOREIGN KEY([documento])
REFERENCES [dbo].[usuario] ([documento])
GO
ALTER TABLE [dbo].[cancelacion] CHECK CONSTRAINT [FK_cancelacion_usuario]
GO

-- %% [markdown]
-- # [FK_estadistica_pago]

-- %%
ALTER TABLE [dbo].[estadistica]  WITH CHECK ADD  CONSTRAINT [FK_estadistica_pago] FOREIGN KEY([pago_id])
REFERENCES [dbo].[pago] ([pago_id])
GO
ALTER TABLE [dbo].[estadistica] CHECK CONSTRAINT [FK_estadistica_pago]
GO

-- %% [markdown]
-- # [FK_pago_cancelacion]

-- %%
ALTER TABLE [dbo].[pago]  WITH CHECK ADD  CONSTRAINT [FK_pago_cancelacion] FOREIGN KEY([cancelacion_id])
REFERENCES [dbo].[cancelacion] ([cancelacion_id])
GO
ALTER TABLE [dbo].[pago] CHECK CONSTRAINT [FK_pago_cancelacion]
GO

-- %% [markdown]
-- # [FK_poliza_seguro]

-- %%
ALTER TABLE [dbo].[poliza]  WITH CHECK ADD  CONSTRAINT [FK_poliza_seguro] FOREIGN KEY([seguro_id])
REFERENCES [dbo].[seguro] ([seguro_id])
GO
ALTER TABLE [dbo].[poliza] CHECK CONSTRAINT [FK_poliza_seguro]
GO

-- %% [markdown]
-- # [segurapp]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [segurapp] SET  READ_WRITE 
GO
